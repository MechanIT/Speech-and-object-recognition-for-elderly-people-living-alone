# %%
# !git clone https://github.com/WongKinYiu/yolov9
# %cd yolov9
# !pip3 install -r requirements.txt -q
# Out:
# Cloning into 'yolov9'...
# remote: Enumerating objects: 778, done.
# remote: Counting objects: 100% (404/404), done.
# remote: Compressing objects: 100% (165/165), done.
# remote: Total 778 (delta 278), reused 278 (delta 228), pack-reused 374
# Receiving objects: 100% (778/778), 3.30 MiB | 28.14 MiB/s, done.
# Resolving deltas: 100% (323/323), done.
# /content/yolov9
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.3/207.3 kB 4.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 9.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 41.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.3/21.3 MB 69.8 MB/s eta 0:00:00

# %%
# %cd /content/yolov9_final_data
# !unzip /content/drive/MyDrive/dataset_for_oss_final.zip
# Out:
# /content/yolov9_final_data
# Archive:  /content/drive/MyDrive/dataset_for_oss_final.zip
#   inflating: dataset_for_oss/data.yaml
#    creating: dataset_for_oss/train/
#    creating: dataset_for_oss/train/images/
#   inflating: dataset_for_oss/train/images/20240618_134148.jpg
#   inflating: dataset_for_oss/train/images/20240618_134149.jpg
#   inflating: dataset_for_oss/train/images/20240618_134150.jpg
#   inflating: dataset_for_oss/train/images/20240618_134153.jpg
#   inflating: dataset_for_oss/train/images/20240618_134155.jpg
#   inflating: dataset_for_oss/train/images/20240618_134156.jpg
#   inflating: dataset_for_oss/train/images/20240618_134159.jpg
#   inflating: dataset_for_oss/train/images/20240618_134200.jpg
#   inflating: dataset_for_oss/train/images/20240618_134202(0).jpg
#   inflating: dataset_for_oss/train/images/20240618_134203.jpg
#   inflating: dataset_for_oss/train/images/20240618_134206(0).jpg
#   inflating: dataset_for_oss/train/images/20240618_134207.jpg
# ...

# %%
# !python /content/yolov9/train_dual.py --workers 8 --device 0 --batch 8 --data /content/yolov9_final_data/dataset_for_oss/data.yaml --img 640 --cfg /content/yolov9/models/detect/yolov9-c.yaml --weights '' --name yolov9-c --hyp hyp.scratch-high.yaml --min-items 0 --epochs 30
# Out:
# 2024-06-19 03:06:03.723579: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-06-19 03:06:03.723640: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-06-19 03:06:03.727402: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-06-19 03:06:05.551814: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# ...
